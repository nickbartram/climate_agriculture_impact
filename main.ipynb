# %%
# import dependencies
import pandas as pd
import os

# %%
# load crop_calendar_gaul1.csv to DataFrame
crop_calendar_df = pd.read_csv("Resources/crop_calendar_gaul1.csv")
crop_calendar_df.head(20)
# Out:
#    asap0_id;name0_shr;asap1_id;name1_shr;crop_name;sos_s;sos_e;eos_s;eos_e  \
# 0   13;Kyrgyzstan;353;Talas;Wheat (Spring);8;12;28;31
# 1   13;Kyrgyzstan;410;Jalal-Abad;Wheat (Spring);8;...
# 2   13;Kyrgyzstan;600;Batken;Wheat (Spring);8;11;2...
# 3   13;Kyrgyzstan;609;Naryn;Wheat (Spring);10;13;2...
# 4    13;Kyrgyzstan;611;Osh;Wheat (Spring);10;13;28;30
# 5   13;Kyrgyzstan;612;Ysyk-Kol;Wheat (Spring);10;1...
# 6   13;Kyrgyzstan;2392;Chuy;Wheat (Spring);8;12;28;31
# 7   20;Bangladesh;626;Rajshahi;Rice (Aman);16;23;2...
# 8    20;Bangladesh;626;Rajshahi;Rice (Aus);4;13;16;23
# 9   20;Bangladesh;626;Rajshahi;Rice (Boro);35;6;10;15
# 10     20;Bangladesh;626;Rajshahi;Sorghum;16;28;33;36
# 11  20;Bangladesh;750;Chittagong;Rice (Aman);16;23...
# 12  20;Bangladesh;750;Chittagong;Rice (Aus);4;11;1...
# 13  20;Bangladesh;750;Chittagong;Rice (Boro);35;6;...
# 14   20;Bangladesh;750;Chittagong;Sorghum;16;26;33;36
# 15    20;Bangladesh;754;Dhaka;Rice (Aman);16;25;30;36
# ...

# %% [markdown]
# Pandas as loaded the data from 'crop_calendar_gaul1.csv' into a single column.

# %%
# load rainy_season.csv to DataFrame
rainy_season_df = pd.read_csv("Resources/rainy_season.csv")
rainy_season_df.head(20)
# Out:
#     asap1_id                              name1 Unnamed: 2         name1_shr  \
# 0        684  Administrative unit not available        NaN  Unit unavailable
# 1        703                         Badakhshan        NaN        Badakhshan
# 2        343                            Badghis        NaN           Badghis
# 3        696                            Baghlan        NaN           Baghlan
# 4        266                              Balkh        NaN             Balkh
# 5        269                             Bamyan        NaN            Bamyan
# 6       2339                           Daykundi        NaN          Daykundi
# 7        273                              Farah        NaN             Farah
# 8        274                             Faryab        NaN            Faryab
# 9        278                             Ghazni        NaN            Ghazni
# 10       280                               Ghor        NaN              Ghor
# ...
